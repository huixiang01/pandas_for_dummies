# %%
# Made this for I'm the best coder Hackathon 2019.
# And for Future Referrence ^_^
# You can refer to the following link for more detailed notes from my senior in SUTD:
# https://github.com/methylDragon/python-data-tools-reference/blob/master/Pandas/01%20Pandas%20Basics.md
# Most notes from data36.com

# What is pandas?
# Pandas is one of the most popular Python libraries for Data Science and Analytics.
# Aka. SQL of Python
# Helps you to manage two-dimensional data tables in Python. 
# Of course, it has many more features. 
# First, I’ll show you the most important (that is, the most often used) things that you have to know as an Analyst or a Data Scientist.

# %%
# How to install pandas?

# First, you will need to install python from: 
#     https://www.python.org/downloads/
# Please check your OS and python version accordingly and remember to put in the PATH option

# For more details, refer to: 
#     https://www.youtube.com/watch?v=ndrCfBJkkvE&t=402s

# Installing pip on Windows:
# https://www.liquidweb.com/kb/install-pip-windows/

# Anaconda
# https://www.anaconda.com/distribution/
        
# You will need pandas and numpy for this notes
# If you want to see diagram, install matplotlib
# To install pandas and numpy, use CML ^_^
# It is also highly recommended to install jupyter notebook for good referrence

# pip install pandas numpy matplotlib jupyter
# conda install pandas numpy matplotlib jupyter

# It is a convention to refer pandas as pd, numpy as np and matplotlib.pyplot as plt.

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
# There are two types of panda data structures: series and DataFrame
# Series: One dimensional data structure
# DataFrames 2 or more dimensional data structure

# Really seem like matrices and tables because they are! HAHA GOTCHA!
image = mpimg.imread("./Images/series_and_dataframe.png")
plt.imshow(image)
plt.show()

# %%
# Loading a csv. file into pandas DataFrame

# A csv file is a data set that is downloaded online (and you can play with that!)
# Or convert(save as) from your excel file
# (Ya, you can analyse your own excel and play with that TOO!)

# Err...How to do that?

# Let's use pandas_tutorial_read.csv from the same repo as the sample
# (Download it to the same repo as your python file)

# If you want to download the same csv straight to your code:
# Type:

# !wget 46.101.230.157/dilan/pandas_tutorial_read.csv

# ***Please don't put duplicates as python does not know what to read***
# Out:
# --2019-08-27 07:05:13--  http://46.101.230.157/dilan/pandas_tutorial_read.csv
# Connecting to 46.101.230.157:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 110111 (108K) [application/octet-stream]
# Saving to: ‘pandas_tutorial_read.csv.1’
#
# pandas_tutorial_rea 100%[===================>] 107.53K   139KB/s    in 0.8s
#
# 2019-08-27 07:05:15 (139 KB/s) - ‘pandas_tutorial_read.csv.1’ saved [110111/110111]

# %%
# Let's see what data you have!
pd.read_csv('pandas_tutorial_read.csv', 
            delimiter=';')
# Out:
#       2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 0     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 1     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 2     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 3     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 4     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 5     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 6     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 7     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 8     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 9     2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# 10    2018-01-01 00:08:57  read  country_7  2458151272      SEO      Australia
# ...

# %%
# Woops! SO many data! Let's add in table headings!
# FYI, Adding delimiter tells python what to seperate
pd.read_csv('pandas_tutorial_read.csv', 
            delimiter=';', 
            names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])
# Out:
#               my_datetime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
# There is another alternative method to read csv.
url = 'http://46.101.230.157/dilan/pandas_tutorial_read.csv'
column_names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic']
pd.read_csv(url, delimiter=';', names = column_names)
# Out:
#               my_datetime event    country     user_id   source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2     2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3     2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4     2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America
# 5     2018-01-01 00:05:42  read  country_6  2458151266   Reddit  North America
# 6     2018-01-01 00:06:06  read  country_2  2458151267   Reddit         Europe
# 7     2018-01-01 00:06:15  read  country_6  2458151268  AdWords         Europe
# 8     2018-01-01 00:07:21  read  country_7  2458151269  AdWords  North America
# 9     2018-01-01 00:07:29  read  country_5  2458151270   Reddit  North America
# 10    2018-01-01 00:07:57  read  country_5  2458151271  AdWords           Asia
# ...

# %%
# And it is also better to download once... so put that csv in the same repo and do this instead
article_read = pd.read_csv('pandas_tutorial_read.csv', 
                           delimiter=';', 
                           names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])

# %%
# Aiya, I just want first 5 lines.
# Can, no problem
article_read.head()
# Out:
#            my_datetime event    country     user_id   source          topic
# 0  2018-01-01 00:01:01  read  country_7  2458151261      SEO  North America
# 1  2018-01-01 00:03:20  read  country_7  2458151262      SEO  South America
# 2  2018-01-01 00:04:01  read  country_7  2458151263  AdWords         Africa
# 3  2018-01-01 00:04:02  read  country_7  2458151264  AdWords         Europe
# 4  2018-01-01 00:05:03  read  country_8  2458151265   Reddit  North America

# %%
# Last 5 leh?
# Can also.
article_read.tail()
# Out:
#               my_datetime event    country     user_id   source          topic
# 1790  2018-01-01 23:57:14  read  country_2  2458153051  AdWords  North America
# 1791  2018-01-01 23:58:33  read  country_8  2458153052      SEO           Asia
# 1792  2018-01-01 23:59:36  read  country_6  2458153053   Reddit           Asia
# 1793  2018-01-01 23:59:36  read  country_7  2458153054  AdWords         Europe
# 1794  2018-01-01 23:59:38  read  country_5  2458153055   Reddit           Asia

# %%
# How about random five?
# Ofc.
article_read.sample(5)
# Out:
#              my_datetime event    country     user_id  source          topic
# 995  2018-01-01 13:26:19  read  country_6  2458152256     SEO  South America
# 779  2018-01-01 10:32:51  read  country_2  2458152040  Reddit         Europe
# 455  2018-01-01 06:09:33  read  country_7  2458151716     SEO         Europe
# 88   2018-01-01 01:19:01  read  country_5  2458151349  Reddit           Asia
# 775  2018-01-01 10:27:59  read  country_7  2458152036  Reddit         Europe

# %%
# And also, put the parameters if you want other numbers

# %%
# Hmmm... how about specific columns
article_read[['country', 'user_id']]

# And you can change the order by cchanging the order of the list
article_read[['user_id', 'country']]
# Out:
#          user_id    country
# 0     2458151261  country_7
# 1     2458151262  country_7
# 2     2458151263  country_7
# 3     2458151264  country_7
# 4     2458151265  country_8
# 5     2458151266  country_6
# 6     2458151267  country_2
# 7     2458151268  country_6
# 8     2458151269  country_7
# 9     2458151270  country_5
# 10    2458151271  country_5
# 11    2458151272  country_7
# 12    2458151273  country_5
# 13    2458151274  country_2
# 14    2458151275  country_7
# 15    2458151276  country_7
# 16    2458151277  country_8
# 17    2458151278  country_2
# 18    2458151279  country_4
# 19    2458151280  country_2
# 20    2458151281  country_2
# 21    2458151282  country_7
# 22    2458151283  country_2
# 23    2458151284  country_2
# 24    2458151285  country_7
# 25    2458151286  country_2
# 26    2458151287  country_5
# 27    2458151288  country_2
# 28    2458151289  country_2
# 29    2458151290  country_7
# ...          ...        ...
# 1765  2458153026  country_2
# ...

# %%
#You can get series too!
article_read.user_id
# OR
article_read['user_id']
# Out:
# 0       2458151261
# 1       2458151262
# 2       2458151263
# 3       2458151264
# 4       2458151265
# 5       2458151266
# 6       2458151267
# 7       2458151268
# 8       2458151269
# 9       2458151270
# 10      2458151271
# 11      2458151272
# 12      2458151273
# 13      2458151274
# 14      2458151275
# 15      2458151276
# 16      2458151277
# 17      2458151278
# 18      2458151279
# 19      2458151280
# 20      2458151281
# 21      2458151282
# 22      2458151283
# 23      2458151284
# 24      2458151285
# 25      2458151286
# 26      2458151287
# 27      2458151288
# 28      2458151289
# 29      2458151290
#            ...
# 1765    2458153026
# 1766    2458153027
# 1767    2458153028
# 1768    2458153029
# 1769    2458153030
# 1770    2458153031
# 1771    2458153032
# 1772    2458153033
# 1773    2458153034
# 1774    2458153035
# 1775    2458153036
# 1776    2458153037
# 1777    2458153038
# 1778    2458153039
# 1779    2458153040
# 1780    2458153041
# ...

# %%
# Filtering out 
# If you want to see whether the value in the row is true.
article_read.source == 'SEO'
# Out:
# 0        True
# 1        True
# 2       False
# 3       False
# 4       False
# 5       False
# 6       False
# 7       False
# 8       False
# 9       False
# 10      False
# 11       True
# 12      False
# 13      False
# 14      False
# 15       True
# 16       True
# 17      False
# 18       True
# 19      False
# 20      False
# 21      False
# 22      False
# 23      False
# 24      False
# 25      False
# 26       True
# 27       True
# 28      False
# 29      False
#         ...
# 1765    False
# 1766    False
# 1767    False
# 1768    False
# 1769    False
# 1770    False
# 1771    False
# 1772     True
# 1773    False
# 1774    False
# 1775    False
# 1776    False
# 1777     True
# 1778    False
# 1779     True
# 1780    False
# 1781    False
# 1782    False
# 1783    False
# 1784     True
# 1785    False
# 1786    False
# 1787    False
# 1788    False
# 1789    False
# 1790    False
# 1791     True
# 1792    False
# 1793    False
# 1794    False
# ...

# %%
# If you wanna to check info related to the value which is true(rather than plain numbers)
article_read[article_read.source == "SEO"]
# Out:
#               my_datetime event    country     user_id source          topic
# 0     2018-01-01 00:01:01  read  country_7  2458151261    SEO  North America
# 1     2018-01-01 00:03:20  read  country_7  2458151262    SEO  South America
# 11    2018-01-01 00:08:57  read  country_7  2458151272    SEO      Australia
# 15    2018-01-01 00:11:22  read  country_7  2458151276    SEO  North America
# 16    2018-01-01 00:13:05  read  country_8  2458151277    SEO  North America
# 18    2018-01-01 00:13:39  read  country_4  2458151279    SEO  North America
# 26    2018-01-01 00:20:18  read  country_5  2458151287    SEO  North America
# 27    2018-01-01 00:20:44  read  country_2  2458151288    SEO  North America
# 30    2018-01-01 00:24:52  read  country_6  2458151291    SEO  North America
# 41    2018-01-01 00:35:23  read  country_5  2458151302    SEO           Asia
# 54    2018-01-01 00:46:42  read  country_5  2458151315    SEO  North America
# ...

# %%
#And you can combine functions too!
article_read.head()[['country', 'user_id']]
# Out:
#      country     user_id
# 0  country_7  2458151261
# 1  country_7  2458151262
# 2  country_7  2458151263
# 3  country_7  2458151264
# 4  country_8  2458151265

# %%
article_read[['country', 'user_id']].head()
# Out:
#      country     user_id
# 0  country_7  2458151261
# 1  country_7  2458151262
# 2  country_7  2458151263
# 3  country_7  2458151264
# 4  country_8  2458151265

# %%
pd.read_csv('pandas_tutorial_read.csv', delimiter=';', 
            names = ['my_datetime', 'event', 'country', 'user_id', 'source', 'topic'])[['country', 'user_id']].head()
# Out:
#      country     user_id
# 0  country_7  2458151261
# 1  country_7  2458151262
# 2  country_7  2458151263
# 3  country_7  2458151264
# 4  country_8  2458151265

# %%
# Test yourself:
#     Select the user_id, the country and the topic columns for the users who are from country_2! Print the first five rows only!
